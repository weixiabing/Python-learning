# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
data = {
    'name':['张三', '李四', '王五', '小明'],
    'sex':['female', 'female', 'male', 'male'],
    'math':[78, 79, 83, 92],
    'city':['北京', '上海', '广州', '北京']
}
df = pd.DataFrame(data)
df
# Out:
#   name     sex  math city
# 0   张三  female    78   北京
# 1   李四  female    79   上海
# 2   王五    male    83   广州
# 3   小明    male    92   北京

# %%
plt.plot(df.index,df['math'])

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
plt.plot(years,gdp,color='r')

# %%
plt.plot(years,gdp,color='#FFA500')

# %%
plt.plot(years,gdp,linestyle='--')

# %%
plt.plot(years,gdp,linestyle='--',linewidth=5)

# %%
plt.plot(years,gdp,marker='.')

# %%
plt.plot(years,gdp,marker='D')

# %%
plt.plot(years,gdp,'co--')

# %% [markdown]
# # 柱状图

# %%
data = [23, 85, 72, 43, 52]
plt.bar([1,2,3,4,5],data)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(range(len(data)),data,color='royalblue',alpha=0.7)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(range(len(data)),data,color='green',alpha=0.7)
plt.grid(color='#95a5a6',linestyle='--', linewidth=1,axis='y',alpha=0.6)

# %%
data1 = [23, 85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
plt.bar(range(len(data)),data1)
plt.bar(range(len(data)),data2,bottom=data1)
# Out:
# <Container object of 5 artists>

# %%
data1 = [23, 85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
width = 0.3
plt.bar(np.arange(len(data1)),data1,width=width)
plt.bar(np.arange(len(data2))+width,data2,width=width)
# Out:
# <Container object of 5 artists>

# %%
data1 = [23, 85, 72, 43, 52]
plt.barh(range(len(data1)),data1)
# Out:
# <Container object of 5 artists>

# %%
data = [23, 85, 72, 43, 52]
labels = ['A','B','C','D','E']
plt.xticks(range(len(data)),labels) #设置刻度和标签
plt.bar(range(len(data)),data)
# Out:
# <Container object of 5 artists>

# %%
data = [23, 85, 72, 43, 52]
labels = ['A','B','C','D','E']
plt.xticks(range(len(data)),labels) #设置刻度和标签
plt.xlabel('Class')
plt.ylabel('Amounts')
plt.title('Example1')
plt.bar(range(len(data)),data)
# Out:
# <Container object of 5 artists>

# %%
data1 = [23, 85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
width = 0.3
plt.bar(np.arange(len(data1)),data1,width=width,label='one')
plt.bar(np.arange(len(data2))+width,data2,width=width,label='two')
plt.legend()

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sex_mean = tips.groupby('sex')['tip'].mean()
sex_mean
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
labels = list(sex_mean.index)  #刻度标签
plt.xlabel('sex')  #设置X轴标签
plt.ylabel('tip')  #设置Y轴标签
plt.bar(range(len(labels)),sex_mean,width=0.5)
plt.xticks(range(len(labels)),labels,fontsize=12) #设置刻度和刻度标签
# Out:
# ([<matplotlib.axis.XTick at 0xca1e400>, <matplotlib.axis.XTick at 0xca27080>],
#  <a list of 2 Text xticklabel objects>)

# %%
X = np.random.randn(100)
Y = np.random.randn(100)
plt.scatter(X,Y)

# %%
plt.scatter(X,Y,color='red',marker='D')

# %%
x = np.random.normal(size=100)

# %%
plt.hist(x,bins=30)
# Out:
# (array([ 2.,  0.,  1.,  0.,  3.,  1.,  4.,  5.,  4.,  3.,  3.,  4.,  7.,
#          5.,  3.,  9.,  6.,  4.,  8.,  2.,  8.,  1.,  5.,  2.,  2.,  0.,
#          1.,  4.,  1.,  2.]),
#  array([-2.23080311, -2.08556341, -1.94032372, -1.79508402, -1.64984432,
#         -1.50460462, -1.35936492, -1.21412522, -1.06888553, -0.92364583,
#         -0.77840613, -0.63316643, -0.48792673, -0.34268704, -0.19744734,
#         -0.05220764,  0.09303206,  0.23827176,  0.38351145,  0.52875115,
#          0.67399085,  0.81923055,  0.96447025,  1.10970995,  1.25494964,
#          1.40018934,  1.54542904,  1.69066874,  1.83590844,  1.98114813,
#          2.12638783]),
#  <a list of 30 Patch objects>)

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
ax1.scatter(years,gdp)
ax2.plot(years,gdp)
ax3.bar(years,gdp)
# Out:
# <Container object of 7 artists>

# %%
fig,axes = plt.subplots(2,2,figsize=(10,6))
axes[1,0].plot(years,gdp)

# %%
fig,axes = plt.subplots(2,2)

# %%
fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.3,hspace=0.3)

# %%
data = [23, 85, 72, 43, 52]
labels = ['A','B','C','D','E']
plt.xticks(range(len(data)),labels) #设置刻度和标签
plt.xlabel('Class')
plt.ylabel('Amounts')
plt.title('Example1')
plt.bar(range(len(data)),data)
for x,y in zip(range(len(data)),data):
    plt.text(x, y,y, ha='center', va= 'bottom')  #文本注解

# %%
plt.style.use('ggplot')
data = [23, 85, 72, 43, 52]
labels = ['A','B','C','D','E']
plt.xticks(range(len(data)),labels) #设置刻度和标签
plt.xlabel('Class')
plt.ylabel('Amounts')
plt.title('Example1')
plt.bar(range(len(data)),data)
for x,y in zip(range(len(data)),data):
    plt.text(x, y,y, ha='center', va= 'bottom')  #文本注解

# %%
plt.title('案例')
# Out:
# Text(0.5,1,'案例')

# %%
plt.rcParams['font.sans-serif'] = ['simhei'] #指定默认字体
plt.rcParams['axes.unicode_minus'] = False   #解决保存图像是负号'-'显示为方块的问题
plt.title('案例')
# Out:
# Text(0.5,1,'案例')
